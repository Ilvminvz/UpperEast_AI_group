# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
group2_df = pd.read_csv('C:\\Users\\dell\\Desktop\\Group2.csv')

# %%
group2_df
# Out:
#                       FullName                        Email         Phone  \
# 0                AHMED IDDRISS   iddrissahmed2012@gmail.com     245209671
# 1          AMOAKA TIMOTHY NSOR  amoakatimothynsor@gmail.com     241496635
# 2               ANAFO HUMPHREY     humphreywepare@gmail.cim     543338167
# 3        AWINI EZEKIEL ASAMANI       ezekielawini@gmail.com     247522483
# 4         Abongo Matthew Aduko        abongoaduko@gmail.com     540636920
# 5        Aduboa Moses Aboliwen        aduboamoses@gmail.com  233549293812
# 6        Agana Blaise Adombila        aganablaise@gmail.com     202435031
# 7           Alhassan A.Suwaidu    alhassahsuwaidu@gmail.com     245304254
# 8            Anita Njeri Thuku      anita.thuku93@gmail.com  254716988492
# 9      Asakeya Asekziko Eugine           aseug568@gmail.com     205381477
# 10                      Asulba     barikisuahmed1@gmail.com     243929267
# 11              Atuah Jonathan      aposiyine2014@gmail.com     543638301
# ...

# %%
#Editing names to make it easier to categorize
group2_df.loc[10,'Location'] = 'Bolgatanga'
group2_df.loc[18,'Location'] = 'Bolgatanga'
group2_df.loc[21,'Location'] = 'Garu'
group2_df
# Out:
#                       FullName                        Email         Phone  \
# 0                AHMED IDDRISS   iddrissahmed2012@gmail.com     245209671
# 1          AMOAKA TIMOTHY NSOR  amoakatimothynsor@gmail.com     241496635
# 2               ANAFO HUMPHREY     humphreywepare@gmail.cim     543338167
# 3        AWINI EZEKIEL ASAMANI       ezekielawini@gmail.com     247522483
# 4         Abongo Matthew Aduko        abongoaduko@gmail.com     540636920
# 5        Aduboa Moses Aboliwen        aduboamoses@gmail.com  233549293812
# 6        Agana Blaise Adombila        aganablaise@gmail.com     202435031
# 7           Alhassan A.Suwaidu    alhassahsuwaidu@gmail.com     245304254
# 8            Anita Njeri Thuku      anita.thuku93@gmail.com  254716988492
# 9      Asakeya Asekziko Eugine           aseug568@gmail.com     205381477
# 10                      Asulba     barikisuahmed1@gmail.com     243929267
# 11              Atuah Jonathan      aposiyine2014@gmail.com     543638301
# ...

# %%
group2_df.shape #35 rows and 25 columns
# Out:
# (35, 25)

# %%
group2_df.shape[1]
group2_df.shape[0]
print('ROWS: ' + str(group2_df.shape[0]) + '\n')
print('COLUMNS: ' + str(group2_df.shape[1]))
# Out:
# ROWS: 35
#
# COLUMNS: 25

# %%
#Number of people with programming knowledge
group2_df['ProgrammingKnowledge'].value_counts()
# Out:
# NO     24
# YES    11
# Name: ProgrammingKnowledge, dtype: int64

# %%
group2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 25 columns):
# FullName                            35 non-null object
# Email                               35 non-null object
# Phone                               35 non-null int64
# Location                            35 non-null object
# Region                              35 non-null object
# DateOfBirth                         35 non-null object
# Gender                              35 non-null object
# Schooling                           35 non-null object
# ProgrammingKnowledge                35 non-null object
# Instituition                        35 non-null object
# EducationLevel                      35 non-null object
# CourseStudied                       35 non-null object
# PreferredCityForTrainig             27 non-null object
# EntrepreneurialExperience           35 non-null object
# ProgrammingLanguages                13 non-null object
# ...

# %%
list(group2_df.columns.values)
# Out:
# ['FullName',
#  'Email',
#  'Phone',
#  'Location',
#  'Region',
#  'DateOfBirth',
#  'Gender',
#  'Schooling',
#  'ProgrammingKnowledge',
#  'Instituition',
#  'EducationLevel',
#  'CourseStudied',
#  'PreferredCityForTrainig',
#  'EntrepreneurialExperience',
#  'ProgrammingLanguages',
#  'ProgrammingLevel',
#  'Employed',
#  'CurrenRoleIfEmployed',
#  'Motivation',
#  'CurrentEnrolledInAnyProgram',
#  'FullParticipationForOneMonth',
#  'ReadyToCommitToIncubationProgram',
#  'ConsiderForInternship',
#  'HeardAboutUsThrough',
#  'AIKnowledge']

# %%
#Number of students with A.I. knowledge
group2_df['AIKnowledge'].value_counts()
# Out:
# NO     25
# YES     2
# Name: AIKnowledge, dtype: int64

# %%
group2_df['FullName']
# Out:
# 0                  AHMED IDDRISS
# 1            AMOAKA TIMOTHY NSOR
# 2                 ANAFO HUMPHREY
# 3          AWINI EZEKIEL ASAMANI
# 4           Abongo Matthew Aduko
# 5          Aduboa Moses Aboliwen
# 6          Agana Blaise Adombila
# 7             Alhassan A.Suwaidu
# 8              Anita Njeri Thuku
# 9        Asakeya Asekziko Eugine
# 10                        Asulba
# 11                Atuah Jonathan
# 12                Awuni Andrews
# 13         Ayariga Mark Agingire
# 14     Ayinsum Frederick Akaribo
# 15             BATALIRA RICHARD
# 16             Carlven A. Afelik
# 17         Elias Addah Awupireh
# 18                    Henry Zong
# 19                 ISSAH IBRAHIM
# 20            Joseph Yankey Blay
# 21      Joshua Anamsigiya Nyaaba
# 22            Kenneth Ekow Inkum
# 23              MATILDA AYELTIGE
# 24                MUSAH ABDALLAH
# 25                    MahamaMark
# 26     NATHANIEL AKANLU  ADEWUYI
# 27              Nicholas Asaasim
# ...

# %%
#Number of students who are ready to commit to incubation
group2_df['ReadyToCommitToIncubationProgram'].value_counts()
# Out:
# YES    35
# Name: ReadyToCommitToIncubationProgram, dtype: int64

# %%
#Ways people heard about the program
group2_df['HeardAboutUsThrough'].value_counts()
# Out:
# social media    20
# friends         11
# other            3
# website          1
# Name: HeardAboutUsThrough, dtype: int64

# %%
group2_df['ProgrammingLanguages'].unique()
# Out:
# array(['English, Hausa, Zugu and Twi', nan, 'English, Gurene, Twi',
#        'Python, PHP', 'C++', 'Php', 'PHP',
#        'HTML, CSS, Javascript, PHP, VB.NET', 'Python',
#        'Visual Basic, Java, C++, HTML, PHP',
#        'VB,java,c++,sql,Oracle and cms', 'English,french,twi',
#        'BOLGATANGA', 'HTML, CSS, PHP, JAVASCRIPT'], dtype=object)

# %%
group2_df['EducationLevel'].value_counts()
# Out:
# Bachelors      18
# Diploma        10
# Masters         4
# Others          2
# SHS(Wassce)     1
# Name: EducationLevel, dtype: int64

# %%
#Number of males and females
group2_df['Gender'].value_counts()
# Out:
# male      31
# female     4
# Name: Gender, dtype: int64

# %%
#Getting their location
group2_df['Location'].value_counts()
# Out:
# Bolgatanga        14
# NAVRONGO           4
# Navrongo           4
# BOLGATANGA         4
# Garu               2
# Nairobi, Kenya     1
# Bolgatanga         1
# BAWKU              1
# Sandema            1
# Bawku              1
# Navrongo           1
# Bongo              1
# Name: Location, dtype: int64

# %%
#
lower_grp = group2_df['Location'].str.lower()
lower_grp
# Out:
# 0         bolgatanga
# 1              bawku
# 2           navrongo
# 3              bawku
# 4              bongo
# 5         bolgatanga
# 6         bolgatanga
# 7           navrongo
# 8     nairobi, kenya
# 9         bolgatanga
# 10        bolgatanga
# 11        bolgatanga
# 12       bolgatanga
# 13         navrongo
# 14        bolgatanga
# 15          navrongo
# 16          sandema
# 17          navrongo
# 18        bolgatanga
# 19        bolgatanga
# 20        bolgatanga
# 21              garu
# 22        bolgatanga
# 23        bolgatanga
# 24          navrongo
# 25        bolgatanga
# 26          navrongo
# 27              garu
# 28        bolgatanga
# 29        bolgatanga
# 30        bolgatanga
# 31          navrongo
# 32          navrongo
# 33        bolgatanga
# 34        bolgatanga
# Name: Location, dtype: object

# %%
#Changing all locations to lowercase to get an accurate data of their number
#Only one bolgatanga person is female
#Only one navrongo person had programming knowledge
lower_grp.value_counts()
# Out:
# bolgatanga        18
# navrongo           8
# bawku              2
# garu               2
# sandema            1
# navrongo           1
# nairobi, kenya     1
# bongo              1
# bolgatanga         1
# Name: Location, dtype: int64

# %%
#2nd Method of changing locations to lowercase to get accurate data
group2_df['Location'].apply(lambda x: x.lower()).value_counts()
# Out:
# bolgatanga        18
# navrongo           8
# bawku              2
# garu               2
# sandema            1
# navrongo           1
# nairobi, kenya     1
# bongo              1
# bolgatanga         1
# Name: Location, dtype: int64

# %%
group2_df[['FullName','AIKnowledge']]
# Out:
#                       FullName AIKnowledge
# 0                AHMED IDDRISS         NaN
# 1          AMOAKA TIMOTHY NSOR          NO
# 2               ANAFO HUMPHREY          NO
# 3        AWINI EZEKIEL ASAMANI         NaN
# 4         Abongo Matthew Aduko         YES
# 5        Aduboa Moses Aboliwen          NO
# 6        Agana Blaise Adombila          NO
# 7           Alhassan A.Suwaidu          NO
# 8            Anita Njeri Thuku          NO
# 9      Asakeya Asekziko Eugine          NO
# 10                      Asulba          NO
# 11              Atuah Jonathan          NO
# 12              Awuni Andrews           NO
# 13       Ayariga Mark Agingire         NaN
# 14   Ayinsum Frederick Akaribo          NO
# 15           BATALIRA RICHARD           NO
# 16           Carlven A. Afelik          NO
# 17       Elias Addah Awupireh           NO
# 18                  Henry Zong          NO
# 19               ISSAH IBRAHIM         NaN
# 20          Joseph Yankey Blay          NO
# ...

# %%
group2_df.isnull()
# Out:
#     FullName  Email  Phone  Location  Region  DateOfBirth  Gender  Schooling  \
# 0      False  False  False     False   False        False   False      False
# 1      False  False  False     False   False        False   False      False
# 2      False  False  False     False   False        False   False      False
# 3      False  False  False     False   False        False   False      False
# 4      False  False  False     False   False        False   False      False
# 5      False  False  False     False   False        False   False      False
# 6      False  False  False     False   False        False   False      False
# 7      False  False  False     False   False        False   False      False
# 8      False  False  False     False   False        False   False      False
# 9      False  False  False     False   False        False   False      False
# 10     False  False  False     False   False        False   False      False
# ...

# %%
group2_df.isnull().any()
# Out:
# FullName                            False
# Email                               False
# Phone                               False
# Location                            False
# Region                              False
# DateOfBirth                         False
# Gender                              False
# Schooling                           False
# ProgrammingKnowledge                False
# Instituition                        False
# EducationLevel                      False
# CourseStudied                       False
# PreferredCityForTrainig              True
# EntrepreneurialExperience           False
# ProgrammingLanguages                 True
# ProgrammingLevel                    False
# Employed                            False
# CurrenRoleIfEmployed                 True
# Motivation                          False
# CurrentEnrolledInAnyProgram         False
# FullParticipationForOneMonth        False
# ReadyToCommitToIncubationProgram    False
# ...

# %%
group2_df[group2_df['AIKnowledge'].isnull()]
# Out:
#                       FullName                        Email         Phone  \
# 0                AHMED IDDRISS   iddrissahmed2012@gmail.com     245209671
# 3        AWINI EZEKIEL ASAMANI       ezekielawini@gmail.com     247522483
# 13       Ayariga Mark Agingire        ayarigamark@gmail.com     204225473
# 19               ISSAH IBRAHIM          iissah840@gmail.com     242284992
# 24              MUSAH ABDALLAH    musahabdallah84@gmail.com  233245284783
# 30      PRINCE ESSILFIE AMOAKO       richoheneba1@gmail.com     245830372
# 31  Sulemana ubaidulai kandela  ubaidulaisulemana@gmail.com     508722295
# 33               YUUSIF HARUUN    yuusifharuun999@gmail.com     245094824
#
#       Location      Region               DateOfBirth Gender Schooling  \
# 0   BOLGATANGA  Upper East  1992-02-06T00:00:00.000Z   male        NO
# 3        Bawku  Upper East  1988-12-28T08:00:00.000Z   male        NO
# 13   Navrongo   Upper East  1992-07-21T00:00:00.000Z   male        NO
# ...

# %%
students = [1,11,3,20]
HeardAboutUsThrough = ['website','friends','other','social media']
plt.bar(HeardAboutUsThrough,students)
plt.title('Number Of People & How They Heard Program')
plt.xlabel('Heard About Program Through')
plt.ylabel('Number of people')
plt.grid(True)

# %%
group2_df['Gender'].value_counts().head(35).plot.pie(autopct='%1.2f%%')
plt.show()

# %%
import seaborn as sn
sn.countplot(group2_df['HeardAboutUsThrough'].head(35))

# %%
group2_df['HeardAboutUsThrough'].value_counts().head(35).plot.pie(autopct='%1.2f%%')
plt.show()

# %%
#location_list = ['BAWKU ', 'bongo' ,'NAVRONGO', 'BOLGATANGA' ]

#Bawku = df.loc[df['Location'] == 'BAWKU'].shape[0]
#bongo = df.loc[df['Location'] == 'bongo'].shape[0]
#Navrongo = df.loc[df['Location'] == 'NAVRONGO'].shape[0]
#Bolgatanga = df.loc[df['Location'] == 'BOLGATANGA'].shape[0]

#Location_list = ['Bawku','bongo','Navrongo','Bolgatanga']
#plt.pie(Location_count,labels=Location_list,autopct =' %1.2f%%')
#plt.show()            '''
